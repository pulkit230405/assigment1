# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
df = pd.read_csv('C:\jupyter\Cars.csv')

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
#your code here
print(df.shape)
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
arr = df.columns
print(arr)
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
#your code here
df= df.set_index('name')

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
#your code here
print(df['mpg'].unique())
# Out:
# [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]

# %% [markdown]
# ### 8 Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
#your code here
df['hw']=df['horsepower']/df['weight']
df= df.set_index('hw')
print(df)
# Out:
#            mpg  cylinders  displacement  horsepower  weight  acceleration  \
# hw
# 0.037100  18.0          8         307.0       130.0    3504          12.0
# 0.044679  15.0          8         350.0       165.0    3693          11.5
# 0.043655  18.0          8         318.0       150.0    3436          11.0
# 0.043694  16.0          8         304.0       150.0    3433          12.0
# 0.040591  17.0          8         302.0       140.0    3449          10.5
# ...        ...        ...           ...         ...     ...           ...
# 0.030824  27.0          4         140.0        86.0    2790          15.6
# 0.024413  44.0          4          97.0        52.0    2130          24.6
# 0.036601  32.0          4         135.0        84.0    2295          11.6
# 0.030095  28.0          4         120.0        79.0    2625          18.6
# 0.030147  31.0          4         119.0        82.0    2720          19.4
#
#           model_year  origin                       name
# hw
# 0.037100          70     usa  chevrolet chevelle malibu
# 0.044679          70     usa          buick skylark 320
# 0.043655          70     usa         plymouth satellite
# 0.043694          70     usa              amc rebel sst
# 0.040591          70     usa                ford torino
# ...              ...     ...                        ...
# 0.030824          82     usa            ford mustang gl
# 0.024413          82  europe                  vw pickup
# 0.036601          82     usa              dodge rampage
# 0.030095          82     usa                ford ranger
# 0.030147          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
#your code here
max_hr =df[df['horsepower']==df['horsepower'].max()]
print(max_hr['name'].values[0])
# Out:
# pontiac grand prix

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
#your code here
print(df[df['mpg']>=35])
# Out:
#            mpg  cylinders  displacement  horsepower  weight  acceleration  \
# hw
# 0.042777  35.0          4          72.0        69.0    1613          18.0
# 0.031781  36.0          4          79.0        58.0    1825          18.6
# 0.024181  43.1          4          90.0        48.0    1985          21.5
# 0.036667  36.1          4          98.0        66.0    1800          14.4
# 0.033816  39.4          4          85.0        70.0    2070          18.6
# 0.033333  36.1          4          91.0        60.0    1800          16.4
# 0.041775  35.7          4          98.0        80.0    1915          14.4
# 0.032394  37.3          4          91.0        69.0    2130          14.7
# 0.035448  41.5          4          98.0        76.0    2144          14.7
# 0.030488  38.1          4          89.0        60.0    1968          18.8
# 0.032194  37.2          4          86.0        65.0    2019          16.4
# 0.037798  37.0          4         119.0        92.0    2434          15.0
# 0.030806  46.6          4          86.0        65.0    2110          17.9
# 0.030806  40.8          4          85.0        65.0    2110          19.2
# 0.023022  44.3          4          90.0        48.0    2085          21.7
# 0.020557  43.4          4          90.0        48.0    2335          23.7
# 0.022712  36.4          5         121.0        67.0    2950          19.9
# 0.036216  44.6          4          91.0        67.0    1850          13.8
# NaN       40.9          4          85.0         NaN    1835          17.3
# 0.035200  35.0          4         122.0        88.0    2500          15.1
# 0.033048  39.1          4          79.0        58.0    1755          16.9
# 0.034133  39.0          4          86.0        64.0    1875          16.4
# 0.034091  35.1          4          81.0        60.0    1760          16.1
# 0.032911  37.0          4          85.0        65.0    1975          19.4
# 0.030244  37.7          4          89.0        62.0    2050          17.3
# 0.037374  36.0          4         105.0        74.0    1980          15.3
# 0.033580  37.0          4          91.0        68.0    2025          18.2
# 0.029647  38.0          4         105.0        63.0    2125          14.7
# 0.032941  36.0          4          98.0        70.0    2125          17.3
# 0.040741  36.0          4         120.0        88.0    2160          14.5
# 0.034014  36.0          4         107.0        75.0    2205          14.5
# 0.034097  38.0          4          91.0        67.0    1965          15.0
# 0.033584  38.0          4          91.0        67.0    1995          16.2
# 0.028192  38.0          6         262.0        85.0    3015          17.0
# 0.035443  36.0          4         135.0        84.0    2370          13.0
# 0.024413  44.0          4          97.0        52.0    2130          24.6
#
#           model_year  origin                               name
# hw
# 0.042777          71   japan                        datsun 1200
# 0.031781          77  europe                      renault 5 gtl
# 0.024181          78  europe    volkswagen rabbit custom diesel
# 0.036667          78     usa                        ford fiesta
# 0.033816          78   japan                     datsun b210 gx
# 0.033333          78   japan                   honda civic cvcc
# 0.041775          79     usa        dodge colt hatchback custom
# 0.032394          79  europe                 fiat strada custom
# 0.035448          80  europe                          vw rabbit
# 0.030488          80   japan              toyota corolla tercel
# 0.032194          80   japan                         datsun 310
# 0.037798          80   japan               datsun 510 hatchback
# 0.030806          80   japan                          mazda glc
# 0.030806          80   japan                         datsun 210
# 0.023022          80  europe               vw rabbit c (diesel)
# 0.020557          80  europe                 vw dasher (diesel)
# 0.022712          80  europe                audi 5000s (diesel)
# 0.036216          80   japan                honda civic 1500 gl
# NaN               80  europe               renault lecar deluxe
# 0.035200          80  europe                  triumph tr7 coupe
# 0.033048          81   japan                     toyota starlet
# 0.034133          81     usa                     plymouth champ
# 0.034091          81   japan                   honda civic 1300
# 0.032911          81   japan                     datsun 210 mpg
# 0.030244          81   japan                      toyota tercel
# 0.037374          82  europe                volkswagen rabbit l
# 0.033580          82   japan                 mazda glc custom l
# 0.029647          82     usa             plymouth horizon miser
# 0.032941          82     usa                     mercury lynx l
# 0.040741          82   japan                   nissan stanza xe
# 0.034014          82   japan                       honda accord
# 0.034097          82   japan                        honda civic
# 0.033584          82   japan                      datsun 310 gx
# 0.028192          82     usa  oldsmobile cutlass ciera (diesel)
# 0.035443          82     usa                  dodge charger 2.2
# 0.024413          82  europe                          vw pickup

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
#your code here
fil_df= df[(df['horsepower'] > 100) & (df['weight'] < 3000)]
mc= fil_df['origin'].value_counts().idxmax()
print(mc)
# Out:
# usa

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
#your code here
jap_car = df[df['origin']=='japan']
mean_acc = round(jap_car['acceleration'].mean(),2)
print(f"The average acceleration of Japanese cars is {mean_acc} seconds")
# Out:
# The average acceleration of Japanese cars is 16.17 seconds

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
#your code here
grp = df.groupby('model_year')
avg_mpg = grp['mpg'].mean()
best_y = avg_mpg.idxmax()
print(best_y)
# Out:
# 80

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
med = df['mpg'].median()
hw_max_index = df.index.max()  
b_car = df[(df.index == hw_max_index) & (df['mpg'] > med)]
print(b_car)
# Out:
#            hw   mpg  cylinders  displacement  horsepower  weight  \
# 397  0.030147  31.0          4         119.0        82.0    2720
#
#      acceleration  model_year origin        name
# 397          19.4          82    usa  chevy s-10

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
#your code here
avg_mpg = df.groupby(['model_year', 'origin'])['mpg'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_mpg, x='model_year', y='mpg', hue='origin', marker='o')
plt.title('Average MPG Over the Years by Origin')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.legend(title='Origin')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
#your code here
hue_order = ['japan', 'europe', 'usa']

plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df,
    x='horsepower',
    y='weight',
    hue='origin',
    size='mpg',
    hue_order=hue_order,
    alpha=0.7
)

plt.title('Horsepower vs Weight Colored by Origin and Sized by MPG')
plt.xlabel('Horsepower')
plt.ylabel('Weight')
plt.legend(title='Origin', bbox_to_anchor=(1.05, 1), loc='upper left')  
plt.tight_layout()
plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
#your code here
import pandas as pd

# Step 1: Group by car name and count distinct model years
multi_year_models = df.groupby('name')['model_year'].nunique()
multi_year_models = multi_year_models[multi_year_models > 1].index

# Step 2: Filter only those models
filtered_df = df[df['name'].isin(multi_year_models)]

# Step 3: Group by name and calculate stats
grouped = filtered_df.groupby('name').agg(
    appearances=('model_year', 'nunique'),
    std_mpg=('mpg', 'std'),
    avg_mpg=('mpg', 'mean')
).reset_index()

# Step 4: Filter where std(mpg) < 1.0
consistent_cars = grouped[grouped['std_mpg'] < 1.0]

# Step 5: Sort as per bonus requirement
consistent_cars_sorted = consistent_cars.sort_values(
    by=['appearances', 'avg_mpg'], ascending=[False, False]
).reset_index(drop=True)

# Step 6: Display result
print(consistent_cars_sorted)
# Out:
#                          name  appearances   std_mpg    avg_mpg
# 0            ford galaxie 500            3  0.577350  14.333333
# 1           plymouth fury iii            3  0.577350  14.333333
# 2         toyota corolla 1200            2  0.707107  31.500000
# 3                   mazda 626            2  0.212132  31.450000
# 4           volkswagen rabbit            2  0.353553  29.250000
# 5                datsun pl510            2  0.000000  27.000000
# 6                   saab 99le            2  0.707107  24.500000
# 7              toyota mark ii            2  0.707107  19.500000
# 8                 dodge aspen            2  0.353553  18.850000
# 9   chevrolet chevelle malibu            2  0.707107  17.500000
# 10           amc matador (sw)            2  0.707107  14.500000
# 11      ford gran torino (sw)            2  0.707107  13.500000
# 12                   ford ltd            2  0.707107  13.500000

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
